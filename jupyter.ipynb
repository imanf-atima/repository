# %%
import numpy as np

# %%
numbers=np.array([32,34,36,38,40])

# %%
numbers[0]=100

# %%
print('after modifying first element',numbers)
# Out:
# after modifying first element [100  34  36  38  40]

# %%
numbers[3]=65

# %%
print('after modifuing 3rd element:',numbers)
# Out:
# after modifuing 3rd element: [100  34  36  65  40]

# %%
numbers=np.array([42,43,45,47,51])

# %%
print(numbers[-1])
# Out:
# 51

# %%
print(numbers[-2])
# Out:
# 47

# %%
print(numbers)
# Out:
# [42 43 45 47 51]

# %%
l=[[1,2,3],[4,5,6]]

# %%
l[0,0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 l[0,0]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
arr=np.array([[10,2,3],[4,15,6],[7,18,9]])

# %%
print(arr[0,1])
# Out:
# 2

# %%
print('element at row 2 and column 3 is',arr[1,2])
# Out:
# element at row 2 and column 3 is 6

# %%
print('last low last column is',arr[-1,-1])
# Out:
# last low last column is 9
